# %%
from scipy.stats import norm
from scipy.stats import expon
from scipy.stats import t

import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(-5,5, 100)
plt.plot(x, norm.pdf(x),'r-')
plt.plot(x, norm.pdf(x,1,2),'g-')
plt.plot(x, norm.pdf(x,-1,1),'y-')
plt.plot(x, norm.pdf(x,0,2),'b-')
plt.plot(x, norm.pdf(x,1,0.5), color='orange')

# %%
x = np.linspace(-5,5, 100)
plt.plot(x, t.pdf(x,5),'r-')
plt.plot(x, t.pdf(x,100),'g-')
plt.plot(x, t.pdf(x,5,-1,1),'y-')
plt.plot(x, t.pdf(x,100,-1,1),'b-')
plt.plot(x, t.pdf(x,50,1,0.5),color='orange')

# %% [markdown]
# #####

# %%
x = np.linspace(-2,7, 100)
plt.plot(x, expon.pdf(x),'r-')
plt.plot(x, expon.pdf(x,1,2),'g-')
plt.plot(x, expon.pdf(x,-1,1),'y-')
plt.plot(x, expon.pdf(x,0,2),'b-')
plt.plot(x, expon.pdf(x,1,0.5),'orange')

# %% [markdown]
# Задание2
# c=1/(b-a)=1/(5-0)=0.2
# мат.ожидание= (a+b)/2=2,5
# P(3.5 <x< 7) =0,2*(7-3.5)=0,7
